# %%
install.packages("mclust")
# Out:
# Updating HTML index of packages in '.Library'
# Making 'packages.html' ... done

# %%
packageVersion("mclust")
# Out:
# [1] ‘5.2.2’

# %%
install.packages("lsa")
# Out:
# also installing the dependency ‘SnowballC’
#
# Updating HTML index of packages in '.Library'
# Making 'packages.html' ... done

# %%
install.packages("reshape")
# Out:
# Updating HTML index of packages in '.Library'
# Making 'packages.html' ... done

# %%
install.packages("pryr")
# Out:
# Updating HTML index of packages in '.Library'
# Making 'packages.html' ... done

# %%
rmarkdown::render('pipeline.Rmd')
# Out:
# processing file: pipeline.Rmd
#   |.                                                                |   1%
#   ordinary text without R code
#
#   |.                                                                |   2%
# label: unnamed-chunk-1 (with options)
# List of 2
#  $ echo   : symbol F
#  $ warning: symbol F
#
#   |..                                                               |   3%
#    inline R code fragments
#
#   |...                                                              |   4%
# label: unnamed-chunk-2 (with options)
# List of 1
#  $ echo: symbol F
#
#   |...                                                              |   5%
#   ordinary text without R code
#
#   |....                                                             |   6%
# label: unnamed-chunk-3 (with options)
# List of 3
#  $ echo   : symbol F
#  $ message: symbol F
#  $ warning: symbol F
#
#   |.....                                                            |   7%
#   ordinary text without R code
#
#   |.....                                                            |   8%
# label: unnamed-chunk-4 (with options)
# List of 1
#  $ echo: symbol F
#
#   |......                                                           |   9%
#   ordinary text without R code
#
#   |.......                                                          |  10%
# label: unnamed-chunk-5 (with options)
# List of 1
#  $ echo: symbol F
#
#   |.......                                                          |  11%
#   ordinary text without R code
#
#   |........                                                         |  12%
# label: unnamed-chunk-6 (with options)
# List of 1
#  $ echo: symbol F
#
#   |.........                                                        |  14%
#   ordinary text without R code
#
#   |.........                                                        |  15%
# label: unnamed-chunk-7 (with options)
# List of 2
#  $ message: symbol F
#  $ echo   : symbol F
# Joining, by = c("Well", "Plate", "rep", "specificCMPO", "specificName", "siRNA", "EnsemblID", "symbol", "CMPO term(s)", "CMPO ID(s)", "IC", "tag", "class", "Edge Features () [0]", "Edge Features () [1]", "Edge Features () [2]", "Edge Features () [3]", "Edge Features () [4]", "Edge Features () [5]", "Edge Features () [6]", "Edge Features () [7]", "Edge Features () [8]", "Edge Features () [9]", "Edge Features () [10]", "Edge Features () [11]", "Edge Features () [12]", "Edge Features () [13]", "Edge Features () [14]", "Edge Features () [15]", "Edge Features () [16]", "Edge Features () [17]", "Edge Features () [18]", "Edge Features () [19]", "Edge Features () [20]", "Edge Features () [21]", "Edge Features () [22]", "Edge Features () [23]", "Edge Features () [24]", "Edge Features () [25]", "Edge Features () [26]", "Edge Features () [27]", "Otsu Object Features () [0]", "Otsu Object Features () [1]", "Otsu Object Features () [2]", "Otsu Object Features () [3]", "Otsu Object Features () [4]", "Otsu Object Features () [5]", "Otsu Object Features () [6]", "Otsu Object Features () [7]", "Otsu Object Features () [8]", "Otsu Object Features () [9]", "Otsu Object Features () [10]", "Otsu Object Features () [11]", "Otsu Object Features () [12]", "Otsu Object Features () [13]", "Otsu Object Features () [14]", "Otsu Object Features () [15]", "Otsu Object Features () [16]", "Otsu Object Features () [17]", "Otsu Object Features () [18]", "Otsu Object Features () [19]", "Otsu Object Features () [20]", "Otsu Object Features () [21]", "Otsu Object Features () [22]", "Otsu Object Features () [23]", "Otsu Object Features () [24]", "Otsu Object Features () [25]", "Otsu Object Features () [26]", "Otsu Object Features () [27]", "Otsu Object Features () [28]", "Otsu Object Features () [29]", "Otsu Object Features () [30]", "Otsu Object Features () [31]", "Otsu Object Features () [32]", "Otsu Object Features () [33]", "Inverse-Otsu Object Features () [0]", "Inverse-Otsu Object Features () [1]", "Inverse-Otsu Object Features () [2]", "Inverse-Otsu Object Features () [3]", "Inverse-Otsu Object Features () [4]", "Inverse-Otsu Object Features () [5]", "Inverse-Otsu Object Features () [6]", "Inverse-Otsu Object Features () [7]", "Inverse-Otsu Object Features () [8]", "Inverse-Otsu Object Features () [9]", "Inverse-Otsu Object Features () [10]", "Inverse-Otsu Object Features () [11]", "Inverse-Otsu Object Features () [12]", "Inverse-Otsu Object Features () [13]", "Inverse-Otsu Object Features () [14]", "Inverse-Otsu Object Features () [15]", "Inverse-Otsu Object Features () [16]", "Inverse-Otsu Object Features () [17]", "Inverse-Otsu Object Features () [18]", "Inverse-Otsu Object Features () [19]", "Inverse-Otsu Object Features () [20]", "Inverse-Otsu Object Features () [21]", "Inverse-Otsu Object Features () [22]", "Inverse-Otsu Object Features () [23]", "Inverse-Otsu Object Features () [24]", "Inverse-Otsu Object Features () [25]", "Inverse-Otsu Object Features () [26]", "Inverse-Otsu Object Features () [27]", "Inverse-Otsu Object Features () [28]", "Inverse-Otsu Object Features () [29]", "Inverse-Otsu Object Features () [30]", "Inverse-Otsu Object Features () [31]", "Inverse-Otsu Object Features () [32]", "Inverse-Otsu Object Features () [33]", "Gabor Textures () [0]", "Gabor Textures () [1]", "Gabor Textures () [2]", "Gabor Textures () [3]", "Gabor Textures () [4]", "Gabor Textures () [5]", "Gabor Textures () [6]", "Chebyshev-Fourier Coefficients () [0]", "Chebyshev-Fourier Coefficients () [1]", "Chebyshev-Fourier Coefficients () [2]", "Chebyshev-Fourier Coefficients () [3]", "Chebyshev-Fourier Coefficients () [4]", "Chebyshev-Fourier Coefficients () [5]", "Chebyshev-Fourier Coefficients () [6]", "Chebyshev-Fourier Coefficients () [7]", "Chebyshev-Fourier Coefficients () [8]", "Chebyshev-Fourier Coefficients () [9]", "Chebyshev-Fourier Coefficients () [10]", "Chebyshev-Fourier Coefficients () [11]", "Chebyshev-Fourier Coefficients () [12]", "Chebyshev-Four ...
#   |..........                                                       |  16%
#   ordinary text without R code
#
#   |...........                                                      |  17%
# label: unnamed-chunk-8 (with options)
# List of 1
#  $ echo: symbol F
#
#   |............                                                     |  18%
#   ordinary text without R code
#
#   |............                                                     |  19%
# label: unnamed-chunk-9 (with options)
# List of 1
#  $ echo: symbol F
#
#   |.............                                                    |  20%
#   ordinary text without R code
#
#   |..............                                                   |  21%
# label: unnamed-chunk-10 (with options)
# List of 1
#  $ echo: symbol F
#
#   |..............                                                   |  22%
#   ordinary text without R code
#
#   |...............                                                  |  23%
# label: unnamed-chunk-11 (with options)
# List of 1
#  $ echo: symbol F
#
#   |................                                                 |  24%
#   ordinary text without R code
#
#   |................                                                 |  25%
# label: unnamed-chunk-12 (with options)
# List of 1
#  $ echo: symbol F
#
#   |.................                                                |  26%
#   ordinary text without R code
#
#   |..................                                               |  27%
# label: unnamed-chunk-13 (with options)
# List of 1
#  $ echo: symbol F
#
#   |..................                                               |  28%
#   ordinary text without R code
#
#   |...................                                              |  29%
# label: unnamed-chunk-14 (with options)
# List of 1
#  $ echo: symbol F
#
#   |....................                                             |  30%
#    inline R code fragments
#
#   |....................                                             |  31%
# label: unnamed-chunk-15 (with options)
# List of 1
#  $ echo: symbol F
#
#   |.....................                                            |  32%
#   ordinary text without R code
#
#   |......................                                           |  33%
# label: unnamed-chunk-16 (with options)
# List of 1
#  $ echo: symbol F
#
#   |......................                                           |  34%
#   ordinary text without R code
#
#   |.......................                                          |  35%
# label: unnamed-chunk-17 (with options)
# List of 1
#  $ echo: symbol F
#
#   |........................                                         |  36%
#   ordinary text without R code
#
#   |........................                                         |  38%
# label: unnamed-chunk-18 (with options)
# List of 1
#  $ echo: symbol F
#
#   |.........................                                        |  39%
#   ordinary text without R code
#
#   |..........................                                       |  40%
# label: unnamed-chunk-19 (with options)
# List of 1
#  $ echo: symbol F
#
#   |..........................                                       |  41%
#   ordinary text without R code
#
#   |...........................                                      |  42%
# label: unnamed-chunk-20 (with options)
# List of 1
#  $ echo: symbol F
#
#   |............................                                     |  43%
#   ordinary text without R code
#
#   |............................                                     |  44%
# label: unnamed-chunk-21 (with options)
# List of 1
#  $ echo: symbol F
#
#   |.............................                                    |  45%
#   ordinary text without R code
#
#   |..............................                                   |  46%
# label: unnamed-chunk-22 (with options)
# List of 1
#  $ echo: symbol F
#
#   |..............................                                   |  47%
#   ordinary text without R code
#
#   |...............................                                  |  48%
# label: unnamed-chunk-23 (with options)
# List of 4
#  $ fig.height: num 4
#  $ fig.width : num 8
#  $ message   : symbol F
#  $ echo      : symbol F
#
#   |................................                                 |  49%
#    inline R code fragments
#
#   |................................                                 |  50%
# label: unnamed-chunk-24 (with options)
# List of 1
#  $ echo: symbol F
#
#   |.................................                                |  51%
#   ordinary text without R code
#
#   |..................................                               |  52%
# label: unnamed-chunk-25 (with options)
# List of 1
#  $ echo: symbol F
#
#   |...................................                              |  53%
#    inline R code fragments
#
#   |...................................                              |  54%
# label: unnamed-chunk-26 (with options)
# List of 1
#  $ echo: symbol F
#
#   |....................................                             |  55%
#   ordinary text without R code
#
#   |.....................................                            |  56%
# label: unnamed-chunk-27 (with options)
# List of 1
#  $ echo: symbol F
#
#   |.....................................                            |  57%
#   ordinary text without R code
#
#   |......................................                           |  58%
# label: unnamed-chunk-28 (with options)
# List of 1
#  $ echo: symbol F
#
#   |.......................................                          |  59%
#    inline R code fragments
#
#   |.......................................                          |  60%
# label: unnamed-chunk-29
#   |........................................                         |  61%
#   ordinary text without R code
#
#   |.........................................                        |  62%
# label: unnamed-chunk-30
#   |.........................................                        |  64%
#    inline R code fragments
#
#   |..........................................                       |  65%
# label: unnamed-chunk-31 (with options)
# List of 1
#  $ echo: symbol F
#
#   |...........................................                      |  66%
#    inline R code fragments
#
#   |...........................................                      |  67%
# label: unnamed-chunk-32 (with options)
# List of 1
#  $ echo: symbol F
#
#   |............................................                     |  68%
#   ordinary text without R code
#
#   |.............................................                    |  69%
# label: unnamed-chunk-33 (with options)
# List of 2
#  $ echo   : symbol F
#  $ message: symbol F
#
#   |.............................................                    |  70%
#   ordinary text without R code
#
#   |..............................................                   |  71%
# label: unnamed-chunk-34 (with options)
# List of 1
#  $ echo: symbol F
#
#   |...............................................                  |  72%
#    inline R code fragments
#
#   |...............................................                  |  73%
# label: unnamed-chunk-35 (with options)
# List of 4
#  $ fig.height: num 3
#  $ fig.width : num 9
#  $ message   : symbol F
#  $ echo      : symbol F
#
#   |................................................                 |  74%
#    inline R code fragments
#
#   |.................................................                |  75%
# label: unnamed-chunk-36
#   |.................................................                |  76%
#    inline R code fragments
#
#   |..................................................               |  77%
# label: unnamed-chunk-37 (with options)
# List of 1
#  $ echo: symbol F
#
#   |...................................................              |  78%
#    inline R code fragments
#
#   |...................................................              |  79%
# label: unnamed-chunk-38
#   |....................................................             |  80%
#    inline R code fragments
#
#   |.....................................................            |  81%
# label: unnamed-chunk-39 (with options)
# List of 1
#  $ echo: symbol F
#
#   |.....................................................            |  82%
#    inline R code fragments
#
#   |......................................................           |  83%
# label: unnamed-chunk-40
#   |.......................................................          |  84%
#    inline R code fragments
#
#   |........................................................         |  85%
# label: unnamed-chunk-41 (with options)
# List of 1
#  $ echo: symbol F
#
#   |........................................................         |  86%
#   ordinary text without R code
#
#   |.........................................................        |  88%
# label: unnamed-chunk-42 (with options)
# List of 1
#  $ echo: symbol F
#
#   |..........................................................       |  89%
#   ordinary text without R code
#
#   |..........................................................       |  90%
# label: unnamed-chunk-43 (with options)
# List of 3
#  $ fig.height: num 10
#  $ fig.width : num 10
#  $ echo      : symbol F
#
#   |...........................................................      |  91%
#   ordinary text without R code
#
#   |............................................................     |  92%
# label: unnamed-chunk-44 (with options)
# List of 1
#  $ echo: symbol F
#
#   |............................................................     |  93%
#   ordinary text without R code
#
#   |.............................................................    |  94%
# label: unnamed-chunk-45 (with options)
# List of 3
#  $ echo   : symbol F
#  $ warning: symbol F
#  $ message: symbol F
#
#   |..............................................................   |  95%
#   ordinary text without R code
#
#   |..............................................................   |  96%
# label: unnamed-chunk-46 (with options)
# List of 1
#  $ echo: symbol F
#
#   |...............................................................  |  97%
#   ordinary text without R code
#
#   |................................................................ |  98%
# label: unnamed-chunk-47 (with options)
# List of 3
#  $ echo   : symbol F
#  $ warning: symbol F
#  $ message: symbol F
#
#   |................................................................ |  99%
#   ordinary text without R code
#
#   |.................................................................| 100%
# label: unnamed-chunk-48 (with options)
# List of 2
#  $ cache: logi FALSE
#  $ echo : symbol F
# output file: pipeline.knit.md
# /usr/bin/pandoc +RTS -K512m -RTS pipeline.utf8.md --to html --from markdown+autolink_bare_uris+ascii_identifiers+tex_math_single_backslash --output pipeline.html --smart --email-obfuscation none --self-contained --standalone --section-divs --template /opt/conda/lib/R/library/rmarkdown/rmd/h/default.html --no-highlight --variable highlightjs=1 --variable 'theme:bootstrap' --include-in-header /tmp/RtmpwZBPcY/rmarkdown-str5948afa416.html --mathjax --variable 'mathjax-url:https://cdn.mathjax.org/mathjax/latest/MathJax.js?config=TeX-AMS-MML_HTMLorMML'
# Output created: pipeline.html

# %%
str(prob_test_belong_control1)
# Out:
#  Named num [1:352] NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN ...
#  - attr(*, "names")= chr [1:352] "INPP5F_213187_W00002" "G6PC3_105918_W00003" "INCENP_28431_W00004**********" "ABCC3_118151_W00006" ...

# %%
nrow(data)
# Out:
# [1] 376

# %%
data$`Edge Features () [14]`
# Out:
# NULL

# %%
data$Well
# Out:
#   [1] W00002 W00003 W00004 W00005 W00006 W00007 W00008 W00009 W00010 W00011
#  [11] W00012 W00013 W00014 W00015 W00016 W00017 W00018 W00019 W00020 W00021
#  [21] W00022 W00023 W00024 W00025 W00026 W00027 W00028 W00029 W00030 W00031
#  [31] W00032 W00033 W00034 W00035 W00036 W00037 W00038 W00039 W00040 W00041
#  [41] W00042 W00043 W00044 W00045 W00046 W00047 W00048 W00049 W00050 W00051
#  [51] W00052 W00053 W00054 W00055 W00056 W00057 W00058 W00059 W00060 W00061
#  [61] W00062 W00063 W00064 W00065 W00066 W00067 W00068 W00069 W00070 W00071
#   [5]
#   [6] CMPO:0000030|CMPO:0000345|CMPO:0000202
#   [7]
#   [8]
#   [9]
#  [10]
#  [11]
#  [12] CMPO:0000345
#  [13]
#  [14] CMPO:0000346|CMPO:0000346
#  [15]
#  [16] CMPO:0000241
#  [17]
#  [18] CMPO:0000202|CMPO:0000318
#  [19]
#  [20]
#  [21]
#  [22]
#  [23] CMPO:0000030
#  [24]
#  [25] CMPO:0000346|CMPO:0000346
#  [26]
#  [27]
#  [28] CMPO:0000213|CMPO:0000030|CMPO:0000213|CMPO:0000140|CMPO:0000345
#  [29]
#  [30]
#  [31]
#  [32]
#  [33]
#  [34]
#  [35]
#  [36]
#  [37] CMPO:0000213|CMPO:0000236|CMPO:0000237
#  [38]
#  [39]
#  [40]
#  [41]
#  [42]
#  [43]
#  [44]
#  [45] CMPO:0000213
#  [46] CMPO:0000213
#  [47]
#  [48] CMPO:0000346|CMPO:0000346
#  [49] CMPO:0000213|CMPO:0000157|CMPO:0000140|CMPO:0000346
#  [50]
#  [51] CMPO:0000346|CMPO:0000346
#  [52] CMPO:0000157|CMPO:0000345
#  [53] CMPO:0000140|CMPO:0000345|CMPO:0000346
#  [54] CMPO:0000140
#  [55] CMPO:0000213|CMPO:0000157|CMPO:0000140
#  [56]
#  [57]
#  [58]
#  [59]
#  [60]
#  [61]
#  [62] CMPO:0000346|CMPO:0000346
#  [63] CMPO:0000140
#  [64] CMPO:0000241
#  [65] CMPO:0000345
#  [66] CMPO:0000318
#  [67] CMPO:0000318
#  [68]
#  [69]
#  [70]
#  [71]
#  [72]
#  [73] CMPO:0000346|CMPO:0000346
#  [74]
#  [75]
#  [76]
#  [77] CMPO:0000345
#  [78] CMPO:0000241
#  [79] CMPO:0000346
#  [80] CMPO:0000318
#  [81]
#  [82]
#  [83] CMPO:0000241
#  [84] CMPO:0000213|CMPO:0000157|CMPO:0000326
#  [85]
#  [86]
#  [87]
#  [88]
#  [89] CMPO:0000140|CMPO:0000345
#  [90] CMPO:0000157|CMPO:0000345
#  [91]
#  [92]
#  [93]
#  [94]
#  [95]
#  [96]
#  [97]
#  [98] CMPO:0000241
#  [99] CMPO:0000140|CMPO:0000346
# [100]
# [101]
# [102] CMPO:0000318
# [103] CMPO:0000345
# [104]
# [105] CMPO:0000213|CMPO:0000157
# [106]
# [107] CMPO:0000157|CMPO:0000344|CMPO:0000202
# [108] CMPO:0000345
# [109]
# [110] CMPO:0000241|CMPO:0000346
# [111]
# [112]
# [113]
# [114] CMPO:0000319
# [115] CMPO:0000345
# [116]
# [117]
# [118]
# [119]
# [120] CMPO:0000140
# [121] CMPO:0000346
# [122]
# [123]
# [124]
# [125]
# [126]
# [127]
# [128]
# [129] CMPO:0000213|CMPO:0000318
# [130] CMPO:0000318
# [131]
# [132]
# [133]
# [134]
# [135] CMPO:0000213
# [136]
# [137]
# [138] CMPO:0000213|CMPO:0000157
# [139]
# [140]
# [141]
# [142]
# [143]
# [312] CMPO:0000140
# [313]
# [314]
# [315]
# [316] CMPO:0000345
# [317]
# [318] CMPO:0000213|CMPO:0000346
# [319]
# [320]
# [321]
# [322] CMPO:0000345
# [323]
# [324]
# [325] CMPO:0000345
# [326]
# [327]
# [328] CMPO:0000140|CMPO:0000345
# [329]
# [330] CMPO:0000345
# [331] CMPO:0000346|CMPO:0000346
# [332]
# [333]
# [334]
# [335]
# [336]
# [337] CMPO:0000346
# [338]
# [339]
# [340] CMPO:0000140
# [341]
# [342] CMPO:0000346|CMPO:0000346
# [343]
# [344]
# [345] CMPO:0000346|CMPO:0000346
# [346] CMPO:0000345
# [347]
# [348] CMPO:0000140|CMPO:0000345
# [349]
# [350] CMPO:0000346
# [351]
# [352] CMPO:0000345
# [353]
# [354] CMPO:0000345|CMPO:0000346
# [355]
# [356] CMPO:0000346|CMPO:0000346
# [357] CMPO:0000237|CMPO:0000346
# [358] CMPO:0000140
# [359]
# [360] CMPO:0000346
# [361] CMPO:0000346
# [362] CMPO:0000345
# [363]
# [364] CMPO:0000030
# [365] CMPO:0000202|CMPO:0000346
# [366] CMPO:0000346|CMPO:0000346
# [367] CMPO:0000346|CMPO:0000346
# [368] CMPO:0000346|CMPO:0000346
# [369] CMPO:0000346|CMPO:0000346
# [370] CMPO:0000346|CMPO:0000346
# [371] CMPO:0000346|CMPO:0000346
# [372] CMPO:0000346|CMPO:0000346
# [373] CMPO:0000346|CMPO:0000346
# [374] CMPO:0000346|CMPO:0000346
# [375] CMPO:0000346|CMPO:0000346
# [376]
# 77 Levels:  CMPO:0000030 ... CMPO:0000346|CMPO:0000346|CMPO:0000319

# %%
data$class
# Out:
#   [1] target   target   target   notarget target   target   target   target
#   [9] target   target   target   notarget target   notarget target   target
#  [17] target   target   target   target   target   target   target   target
#  [25] notarget target   target   target   target   target   notarget target
#  [33] target   target   target   target   target   target   target   target
#  [41] target   target   target   target   target   target   target   target
#  [49] target   target   target   target   target   target   target   target
#  [57] target   target   target   target   target   notarget target   notarget
#  [65] target   target   target   target   target   target   target   target
#  [73] notarget target   target   target   target   target   target   target
#  [81] target   target   target   target   target   notarget target   notarget
#  [89] target   target   target   target   target   target   target   target
#  [97] target   target   target   target   target   target   target   target
# [105] target   target   target   target   target   target   target   target
# [113] target   target   target   target   target   target   target   target
# [121] target   target   target   target   target   target   target   target
# [129] target   target   target   target   target   target   target   target
# [137] target   target   target   target   target   target   target   target
# [145] target   target   target   target   target   target   target   target
# [153] target   target   target   target   target   target   notarget target
# [161] target   target   target   target   target   target   target   target
# [169] target   target   target   target   target   target   notarget target
# [177] target   notarget target   target   target   target   target   target
# [185] target   target   target   notarget target   notarget target   target
# [193] target   target   target   target   target   target   target   target
# [201] target   target   notarget target   target   target   target   target
# [209] target   target   target   target   target   target   target   target
# [217] target   target   target   target   target   target   target   target
# [225] target   notarget target   target   notarget target   target   target
# [233] target   target   target   target   target   target   target   notarget
# [241] target   target   target   target   target   target   target   target
# [249] target   target   target   target   target   target   target   target
# [257] target   target   target   target   target   target   target   target
# [265] target   target   target   target   target   target   target   target
# [273] target   target   target   target   target   target   target   target
# [281] target   target   target   target   target   target   target   target
# [289] target   target   target   target   target   target   target   target
# [297] target   notarget target   target   target   target   target   notarget
# [305] target   target   target   notarget target   target   target   target
# [313] target   target   target   target   target   target   target   target
# [321] target   notarget target   target   target   target   target   target
# [329] target   target   target   target   target   target   target   target
# [337] target   target   target   target   target   target   target   target
# [345] notarget target   target   target   target   target   target   target
# [353] target   target   target   target   target   target   target   target
# [361] target   target   target   target   target   target   target   target
# [369] target   target   target   target   target   target   target   target
# Levels: notarget target

# %%
data$`Edge Features () [0]`
# Out:
# NULL

# %%
originalFeatures[1:3,1:5]
# Out:
#    Edge Features () [0] Edge Features () [1] Edge Features () [2]
# 1   72881               0.002463829          0.007256078
# 11 133875               0.004032808          0.008914484
# 21 107581               0.007088513          0.006449634
#    Edge Features () [3] Edge Features () [4]
# 1  0.005992716          0.01192322
# 11 0.005692489          0.01932862
# 21 0.006486054          0.01309865

# %%
data[1:3,14:17]
# Out:
#    class  PC1       PC2        PC3
# 1  target -2.297227  3.0719257 7.171821
# 11 target -2.837090 -1.6041712 5.607867
# 21 target -2.550193  0.3354151 7.985194

# %%
summary(cc_gmm)
# Out:
# ----------------------------------------------------
# Gaussian finite mixture model fitted by EM algorithm
# ----------------------------------------------------
#
# Mclust EVE (ellipsoidal, equal volume and orientation) model with 2 components:
#
#  log.likelihood  n df       BIC       ICL
#       -530.0159 24 85 -1330.166 -1330.167
#
# Clustering table:
#  1  2
# 14 10

# %%
head(probs)
# Out:
#                               [,1] [,2]
# INPP5F_213187_W00002          NaN  NaN
# G6PC3_105918_W00003           NaN  NaN
# INCENP_28431_W00004********** NaN  NaN
# ABCC3_118151_W00006           NaN  NaN
# INPP5A_16501_W00007           NaN  NaN
# LHPP_105893_W00008            NaN  NaN

# %%
str(pred_testImages)
# Out:
# List of 2
#  $ classification: int(0)
#  $ z             : num [1:352, 1:2] NaN NaN NaN NaN NaN NaN NaN NaN NaN NaN ...
#   ..- attr(*, "logarithm")= logi FALSE
#   ..- attr(*, "modelName")= chr "EVE"
#   ..- attr(*, "returnCode")= num 0
#   ..- attr(*, "dimnames")=List of 2
#   .. ..$ : chr [1:352] "INPP5F_213187_W00002" "G6PC3_105918_W00003" "INCENP_28431_W00004**********" "ABCC3_118151_W00006" ...
#   .. ..$ : NULL

# %%
testClassFeatures[1:5,1:4]
# Out:
#                               PC1       PC2        PC3       PC4
# INPP5F_213187_W00002          -2.297227  3.0719257  7.171821  1.85954551
# G6PC3_105918_W00003           -2.837090 -1.6041712  5.607867 -0.46411312
# INCENP_28431_W00004********** -2.550193  0.3354151  7.985194 -0.03021414
# ABCC3_118151_W00006            1.276704  0.5269571 14.153152  1.02379846
# INPP5A_16501_W00007           -0.302787  1.8147123  6.233111  3.21074432

# %%
(pred_testImages <- predict.Mclust(cc_gmm, testClassFeatures))
# Out:
# $classification
# integer(0)
#
# $z
#                               [,1] [,2]
# INPP5F_213185_W00367           NaN  NaN
# CYP27B1_2466_W00368            NaN  NaN
# SLC1A5_117350_W00369           NaN  NaN
# SLC18A3_120103_W00370          NaN  NaN
# CYP2J2_106227_W00371           NaN  NaN
# SSH1_104936_W00373             NaN  NaN
# SYNJ1_104703_W00374            NaN  NaN
# TPTE2_36400_W00375             NaN  NaN
# SLC7A7_117207_W00376           NaN  NaN
# CYP17A1_2348_W00377            NaN  NaN
# CYP20A1_110400_W00378          NaN  NaN
# DUSP22_104938_W00379           NaN  NaN
# DUSP6_105820_W00380            NaN  NaN
# ABCB10_117449_W00381           NaN  NaN
# SLC16A8_120130_W00382          NaN  NaN
# ATP9A_120157_W00383            NaN  NaN
# ATP8B1_119994_W00384           NaN  NaN
# attr(,"logarithm")
# [1] FALSE
# attr(,"modelName")
# [1] "EVE"
# attr(,"returnCode")
# [1] 0

# %%
pred_testImages$classification
# Out:
# integer(0)

# %%
packageVersion("mclust")
# Out:
# [1] ‘5.1’

# %%
install.packages(c("plotly", "viridis", "ggplot2"))
# Out:
# also installing the dependencies ‘viridisLite’, ‘htmlwidgets’, ‘hexbin’, ‘gridExtra’
#
# Updating HTML index of packages in '.Library'
# Making 'packages.html' ... done

# %%
rmarkdown::render('pipeline.Rmd')
# Out:
# processing file: pipeline.Rmd
#   |.                                                                |   1%
#   ordinary text without R code
#
#   |.                                                                |   2%
# label: unnamed-chunk-1 (with options)
# List of 2
#  $ echo   : symbol F
#  $ warning: symbol F
#
#   |..                                                               |   3%
#    inline R code fragments
#
#   |...                                                              |   4%
# label: unnamed-chunk-2 (with options)
# List of 1
#  $ echo: symbol F
#
#   |...                                                              |   5%
#   ordinary text without R code
#
#   |....                                                             |   6%
# label: unnamed-chunk-3 (with options)
# List of 3
#  $ echo   : symbol F
#  $ message: symbol F
#  $ warning: symbol F
# Attaching package: 'plotly'
#
# The following object is masked from 'package:ggplot2':
#
#     last_plot
#
# The following object is masked from 'package:stats':
#
#     filter
#
# The following object is masked from 'package:graphics':
#
#     layout
#   |.....                                                            |   7%
#   ordinary text without R code
#
#   |.....                                                            |   8%
# label: unnamed-chunk-4 (with options)
# List of 1
#  $ echo: symbol F
#
#   |......                                                           |   9%
#   ordinary text without R code
#
#   |.......                                                          |  10%
# label: unnamed-chunk-5 (with options)
# List of 1
#  $ echo: symbol F
#
#   |.......                                                          |  11%
#   ordinary text without R code
#
#   |........                                                         |  12%
# label: unnamed-chunk-6 (with options)
# List of 1
#  $ echo: symbol F
#
#   |.........                                                        |  14%
#   ordinary text without R code
#
#   |.........                                                        |  15%
# label: unnamed-chunk-7 (with options)
# List of 2
#  $ message: symbol F
#  $ echo   : symbol F
# Loading required package: dplyr
#
# Attaching package: 'dplyr'
#
# The following objects are masked from 'package:stats':
#
#     filter, lag
#
# The following objects are masked from 'package:base':
#
#     intersect, setdiff, setequal, union
#
# Joining, by = c("Well", "Plate", "rep", "specificCMPO", "specificName", "siRNA", "EnsemblID", "symbol", "CMPO term(s)", "CMPO ID(s)", "IC", "tag", "class", "Edge Features () [0]", "Edge Features () [1]", "Edge Features () [2]", "Edge Features () [3]", "Edge Features () [4]", "Edge Features () [5]", "Edge Features () [6]", "Edge Features () [7]", "Edge Features () [8]", "Edge Features () [9]", "Edge Features () [10]", "Edge Features () [11]", "Edge Features () [12]", "Edge Features () [13]", "Edge Features () [14]", "Edge Features () [15]", "Edge Features () [16]", "Edge Features () [17]", "Edge Features () [18]", "Edge Features () [19]", "Edge Features () [20]", "Edge Features () [21]", "Edge Features () [22]", "Edge Features () [23]", "
(with options)
# List of 1
#  $ echo: symbol F
#
#   |............                                                     |  18%
#   ordinary text without R code
#
#   |............                                                     |  19%
# label: unnamed-chunk-9 (with options)
# List of 1
#  $ echo: symbol F
#
#   |.............                                                    |  20%
#   ordinary text without R code
#
#   |..............                                                   |  21%
# label: unnamed-chunk-10 (with options)
# List of 1
#  $ echo: symbol F
#
#   |..............                                                   |  22%
#   ordinary text without R code
#
#   |...............                                                  |  23%
# label: unnamed-chunk-11 (with options)
# List of 1
#  $ echo: symbol F
#
#   |................                                                 |  24%
#   ordinary text without R code
#
#   |................                                                 |  25%
# label: unnamed-chunk-12 (with options)
# List of 1
#  $ echo: symbol F
#
#   |.................                                                |  26%
#   ordinary text without R code
#
#   |..................                                               |  27%
# label: unnamed-chunk-13 (with options)
# List of 1
#  $ echo: symbol F
#
#   |..................                                               |  28%
#   ordinary text without R code
#
#   |...................                                              |  29%
# label: unnamed-chunk-14 (with options)
# List of 1
#  $ echo: symbol F
#
#   |....................                                             |  30%
#    inline R code fragments
#
#   |....................                                             |  31%
# label: unnamed-chunk-15 (with options)
# List of 1
#  $ echo: symbol F
#
#   |.....................                                            |  32%
#   ordinary text without R code
#
#   |......................                                           |  33%
# label: unnamed-chunk-16 (with options)
# List of 1
#  $ echo: symbol F
#
#   |......................                                           |  34%
#   ordinary text without R code
#
#   |.......................                                          |  35%
# label: unnamed-chunk-17 (with options)
# List of 1
#  $ echo: symbol F
#
#   |........................                                         |  36%
#   ordinary text without R code
#
#   |........................                                         |  38%
# label: unnamed-chunk-18 (with options)
# List of 1
#  $ echo: symbol F
#
#   |.........................                                        |  39%
#   ordinary text without R code
#
#   |..........................                                       |  40%
# label: unnamed-chunk-19 (with options)
# List of 1
#  $ echo: symbol F
#
#   |..........................                                       |  41%
#   ordinary text without R code
#
#   |...........................                                      |  42%
# label: unnamed-chunk-20 (with options)
# List of 1
#  $ echo: symbol F
#
#   |............................                                     |  43%
#   ordinary text without R code
#
#   |............................                                     |  44%
# label: unnamed-chunk-21 (with options)
# List of 1
#  $ echo: symbol F
#
#   |.............................                                    |  45%
#   ordinary text without R code
#
#   |..............................                                   |  46%
# label: unnamed-chunk-22 (with options)
# List of 1
#  $ echo: symbol F
#
#   |..............................                                   |  47%
#   ordinary text without R code
#
#   |...............................                                  |  48%
# label: unnamed-chunk-23 (with options)
# List of 4
#  $ fig.height: num 4
#  $ fig.width : num 8
#  $ message   : symbol F
#  $ echo      : symbol F
#
#   |................................                                 |  49%
#    inline R code fragments
#
#   |................................                                 |  50%
# label: unnamed-chunk-24 (with options)
# List of 1
#  $ echo: symbol F
#
#   |.................................                                |  51%
#   ordinary text without R code
#
#   |..................................                               |  52%
# label: unnamed-chunk-25 (with options)
# List of 1
#  $ echo: symbol F
#
#   |...................................                              |  53%
#    inline R code fragments
#
#   |...................................                              |  54%
# label: unnamed-chunk-26 (with options)
# List of 1
#  $ echo: symbol F
#
#   |....................................                             |  55%
#   ordinary text without R code
#
#   |.....................................                            |  56%
# label: unnamed-chunk-27 (with options)
# List of 1
#  $ echo: symbol F
#
#   |.....................................                            |  57%
#   ordinary text without R code
#
#   |......................................                           |  58%
# label: unnamed-chunk-28 (with options)
# List of 1
#  $ echo: symbol F
#
#   |.......................................                          |  59%
#    inline R code fragments
#
#   |.......................................                          |  60%
# label: unnamed-chunk-29
#   |........................................                         |  61%
#   ordinary text without R code
#
#   |.........................................                        |  62%
# label: unnamed-chunk-30
#   |.........................................                        |  64%
#    inline R code fragments
#
#   |..........................................                       |  65%
# label: unnamed-chunk-31 (with options)
# List of 1
#  $ echo: symbol F
#
#   |...........................................                      |  66%
#    inline R code fragments
#
#   |...........................................                      |  67%
# label: unnamed-chunk-32 (with options)
# List of 1
#  $ echo: symbol F
#
#   |............................................                     |  68%
#   ordinary text without R code
#
#   |.............................................                    |  69%
# label: unnamed-chunk-33 (with options)
# List of 2
#  $ echo   : symbol F
#  $ message: symbol F
#
#   |.............................................                    |  70%
#   ordinary text without R code
#
#   |..............................................                   |  71%
# label: unnamed-chunk-34 (with options)
# List of 1
#  $ echo: symbol F
#
#   |...............................................                  |  72%
#    inline R code fragments
#
#   |...............................................                  |  73%
# label: unnamed-chunk-35 (with options)
# List of 4
#  $ fig.height: num 3
#  $ fig.width : num 9
#  $ message   : symbol F
#  $ echo      : symbol F
#
#   |................................................                 |  74%
#    inline R code fragments
#
#   |.................................................                |  75%
# label: unnamed-chunk-36
#   |.................................................                |  76%
#    inline R code fragments
#
#   |..................................................               |  77%
# label: unnamed-chunk-37 (with options)
# List of 1
#  $ echo: symbol F
#
#   |...................................................              |  78%
#    inline R code fragments
#
#   |...................................................              |  79%
# label: unnamed-chunk-38
#   |....................................................             |  80%
#    inline R code fragments
#
#   |.....................................................            |  81%
# label: unnamed-chunk-39 (with options)
# List of 1
#  $ echo: symbol F
#
#   |.....................................................            |  82%
#    inline R code fragments
#
#   |......................................................           |  83%
# label: unnamed-chunk-40
#   |.......................................................          |  84%
#    inline R code fragments
#
#   |........................................................         |  85%
# label: unnamed-chunk-41 (with options)
# List of 1
#  $ echo: symbol F
#
#   |........................................................         |  86%
#   ordinary text without R code
#
#   |.........................................................        |  88%
# label: unnamed-chunk-42 (with options)
# List of 1
#  $ echo: symbol F
#
#   |..........................................................       |  89%
#   ordinary text without R code
#
#   |..........................................................       |  90%
# label: unnamed-chunk-43 (with options)
# List of 3
#  $ fig.height: num 10
#  $ fig.width : num 10
#  $ echo      : symbol F
#
#   |...........................................................      |  91%
#   ordinary text without R code
#
#   |............................................................     |  92%
# label: unnamed-chunk-44 (with options)
# List of 1
#  $ echo: symbol F
#
#   |............................................................     |  93%
#   ordinary text without R code
#
#   |.............................................................    |  94%
# label: unnamed-chunk-45 (with options)
# List of 3
#  $ echo   : symbol F
#  $ warning: symbol F
#  $ message: symbol F
# Quitting from lines 422-424 (pipeline.Rmd)
# Error in library(lsa, quietly = T): there is no package called 'lsa'
# Traceback:
#
# 1. rmarkdown::render("pipeline.Rmd")
# 2. knitr::knit(knit_input, knit_output, envir = envir, quiet = quiet,
#  .     encoding = encoding)
# 3. process_file(text, output)
# 4. withCallingHandlers(if (tangle) process_tangle(group) else process_group(group),
#  .     error = function(e) {
#  .         setwd(wd)
#  .         cat(res, sep = "\n", file = output %n% "")
#  .         message("Quitting from lines ", paste(current_lines(i),
#  .             collapse = "-"), " (", knit_concord$get("infile"),
#  .             ") ")
#  .     })
# 5. process_group(group)
# 6. process_group.block(group)
# 7. call_block(x)
# 8. block_exec(params)
# 9. in_dir(input_dir(), evaluate(code, envir = env, new_device = FALSE,
#  .     keep_warning = !isFALSE(options$warning), keep_message = !isFALSE(options$message),
#  .     stop_on_error = if (options$error && options$include) 0L else 2L,
#  .     output_handler = knit_handlers(options$render, options)))
# 10. evaluate(code, envir = env, new_device = FALSE, keep_warning = !isFALSE(options$warning),
#   .     keep_message = !isFALSE(options$message), stop_on_error = if (options$error &&
#   .         options$include) 0L else 2L, output_handler = knit_handlers(options$render,
#   .         options))
# 11. evaluate_call(expr, parsed$src[[i]], envir = envir, enclos = enclos,
#   .     debug = debug, last = i == length(out), use_try = stop_on_error !=
#   .         2L, keep_warning = keep_warning, keep_message = keep_message,
#   .     output_handler = output_handler, include_timing = include_timing)
# 12. timing_fn(handle(ev <- withCallingHandlers(withVisible(eval(expr,
#   .     envir, enclos)), warning = wHandler, error = eHandler, message = mHandler)))
# 13. handle(ev <- withCallingHandlers(withVisible(eval(expr, envir,
#   .     enclos)), warning = wHandler, error = eHandler, message = mHandler))
# 14. withCallingHandlers(withVisible(eval(expr, envir, enclos)), warning = wHandler,
#   .     error = eHandler, message = mHandler)
# 15. withVisible(eval(expr, envir, enclos))
# 16. eval(expr, envir, enclos)
# 17. eval(expr, envir, enclos)
# 18. measures.get_cosineSimilarityMatrix(features)
# 19. library(lsa, quietly = T)
# 20. stop(txt, domain = NA)

# %%
nrow(data)
# Out:
# [1] 195

# %%
table(data$tag)
# Out:
#  CTRL   MIT OTHER   SEC NO_PH
#     0    29    43    12   111

# %%
utils.sort_vector(table(data$specificName))
# Out:
#                   abnormal chromosome segregation phenotype
#                                                           0
#                            abnormal nucleus shape phenotype
#                                                           0
#      absence of mitotic chromosome decondensation phenotype
#                                                           0
#                               graped micronucleus phenotype
#                                                           0
#               mitotic metaphase plate congression phenotype
#                                                           0
#                                                    notarget
#                                                           0
#                              prometaphase delayed phenotype
#                                                           0
#                strong decrease in rate of protein secretion
#                                                           0
#                                        cell death phenotype
#                                                           2
#                            increased cell movement distance
#                                                           2
#                                 metaphase delayed phenotype
#                                                           2
#                  mild decrease in rate of protein secretion
#                                                           2
#                               increased cell movement speed
#                                                           3
#                                    binuclear cell phenotype
#                                                           6
#                                         proliferating cells
#                                                           8
#                                   mitosis delayed phenotype
#                                                           9
# decreased rate of intracellular protein transport phenotype
#                                                          10
#                            increased nucleus size phenotype
#                                                          12
#        increased variability of nuclear shape in population
#                                                          28
#                                                 nophenotype
#                                                         111

# %%
rmarkdown::render('test_HDF5.Rmd')
# Out:
# Warning message in normalizePath(path, winslash = winslash, mustWork = mustWork):
# “path[1]="test_HDF5.Rmd": No such file or directory”
# Error in tools::file_path_as_absolute(input): file 'test_HDF5.Rmd' does not exist
# Traceback:
#
# 1. rmarkdown::render("test_HDF5.Rmd")
# 2. setwd(dirname(tools::file_path_as_absolute(input)))
# 3. dirname(tools::file_path_as_absolute(input))
# 4. tools::file_path_as_absolute(input)
# 5. stop(gettextf("file '%s' does not exist", x), domain = NA)

# %%
rmarkdown::render('test_HDF5.Rmd')
# Out:
# processing file: test_HDF5.Rmd

# %%
filename
